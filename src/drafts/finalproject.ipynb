# %%
from SRC.foursquare import *
from SRC.geofunc import *
from SRC.mongofunc import connectMongoColl
from SRC.goog import getLocation

import pandas as pd
import geopandas as gpd
from pymongo import MongoClient
import numpy as np
from geopy import distance
from haversine import haversine
# harvesine (lat,long) --> dist in km.

#Carto
from cartoframes.viz import Map, Layer, Layout
from cartoframes.viz.helpers import size_continuous_layer
from cartoframes.viz.widgets import histogram_widget
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-d1b470aef001> in <module>
#      14 #Carto
#      15 from cartoframes.viz import Map, Layer, Layout
# ---> 16 from cartoframes.viz import size_continuous_layer
#      17 from cartoframes.viz.widgets import histogram_widget
#
# ImportError: cannot import name 'size_continuous_layer' from 'cartoframes.viz' (/usr/local/lib/python3.7/site-packages/cartoframes/viz/__init__.py)

# %% [markdown]
# # Geo_Apis
# ### For the best value, let's see the situation of the rest of the filters
# ---

# %%
coord = [40.4143,-3.7016]

# %% [markdown]
# ## 1 | Zara

# %%
zara = tiendaForesquare(name="inditex",limit=20,distance=500,latitude=coord[0],longitude=coord[1])

# %%
df_zara = pd.DataFrame(zara["response"]["venues"])
df_zara
# Out:
#                           id                            name  \
# 0   5a8810f595da0c0fadce5dc1                        Dear Tee
# 1   4b9d27b9f964a520949436e3                            Zara
# 2   5db6dfda2a8b8100086a9260      A|X Madrid Airport Barajas
# 3   544f8c42498eda814f37924c                     typographia
# 4   5341149f498eafdebcf8a78e              Salvador Bachiller
# 5   4bd87669dc4b952162347988                            Maty
# 6   4bf588c794b2a5930fc4abee                         Lefties
# 7   4d11cc3ee212a1cdacff486f                 Elena Hernández
# 8   4c137fe5f1e0b7134ca834bc                       Pronovias
# 9   4bf91723b182c9b6a066785a                     Foot Locker
# 10  55965ffc498e7e817cb1b65d                    Montera Moda
# 11  57237da1498e82cf933ef0db                 El Señor Miyagi
# 12  4c7e2d2bd6543704ef66c2a2                           Sfera
# 13  4c715bef34443704dda2265f                           Mango
# ...

# %%
loc_zara = []
for i in df_zara.location:
    loc_zara.append([float(i['lat']),float(i['lng'])])

# %%
loc_zara
# Out:
# [[40.414396, -3.702246],
#  [40.415755053855534, -3.70325774218464],
#  [40.41414301418716, -3.7030277251869843],
#  [40.41659419293329, -3.7004157762556473],
#  [40.419068386780246, -3.702090366521614],
#  [40.41750765388947, -3.7057526343293823],
#  [40.41557362297838, -3.7032412010149147],
#  [40.41719793772063, -3.7032941078611],
#  [40.416972194176466, -3.705221711103812],
#  [40.41765360767839, -3.704294264316559],
#  [40.41887618851528, -3.702342721490605],
#  [40.41431, -3.7076573],
#  [40.41739229099138, -3.7042130440093137],
#  [40.41774986325988, -3.7045061992506656],
#  [40.41823222124022, -3.704878306990603],
#  [40.415618656906766, -3.7077044136478974],
#  [40.418498, -3.70453],
#  [40.416237, -3.7066228],
#  [40.41836541928007, -3.704800581717741],
#  [40.41415211250404, -3.707469659645076]]

# %%
names = []
for i in df_zara.name:
    names.append(i)

names
# Out:
# ['Dear Tee',
#  'Zara',
#  'A|X Madrid Airport Barajas',
#  'typographia',
#  'Salvador Bachiller',
#  'Maty',
#  'Lefties',
#  'Elena Hernández',
#  'Pronovias',
#  'Foot Locker',
#  'Montera Moda',
#  'El Señor Miyagi',
#  'Sfera',
#  'Mango',
#  'Pull&Bear',
#  'Sombreros La Favorita',
#  'The North Face Madrid Flagship',
#  'Adidas Store',
#  'Zara',
#  'Alpargatería Casa Hernanz']

# %%
stores =  dict(zip(names,loc_zara))

# %%
dfstores = pd.DataFrame(stores)
dfstores = dfstores.T.reset_index().rename(columns={"index":"name",0: "latitude", 1: "longitude"})
geostores = gpd.GeoDataFrame(dfstores, geometry=gpd.points_from_xy(dfstores.longitude, dfstores.latitude))
display(geostores)
# Out:
#                               name   latitude  longitude  \
# 0                         Dear Tee  40.414396  -3.702246
# 1                             Zara  40.418365  -3.704801
# 2       A|X Madrid Airport Barajas  40.414143  -3.703028
# 3                      typographia  40.416594  -3.700416
# 4               Salvador Bachiller  40.419068  -3.702090
# 5                             Maty  40.417508  -3.705753
# 6                          Lefties  40.415574  -3.703241
# 7                  Elena Hernández  40.417198  -3.703294
# 8                        Pronovias  40.416972  -3.705222
# 9                      Foot Locker  40.417654  -3.704294
# 10                    Montera Moda  40.418876  -3.702343
# 11                 El Señor Miyagi  40.414310  -3.707657
# 12                           Sfera  40.417392  -3.704213
# 13                           Mango  40.417750  -3.704506
# 14                       Pull&Bear  40.418232  -3.704878
# ...

# %%
# Add row of likes and comment

# %% [markdown]
# ## 2 | Starbucks

# %%
dfst = pd.read_csv("INPUT/starbucks.csv")
dfst.head()
# Out:
#        Brand  Store Number                         Name Ownership Type  \
# 0  Starbucks         11854               Epping Main St  Company Owned
# 1  Starbucks         79420      Stop & Shop-Exeter #204       Licensed
# 2  Starbucks          3872      Target Greenland T-2530       Licensed
# 3  Starbucks         13448       Seabrook, Lafayette Rd  Company Owned
# 4  Starbucks         10325  Portsmouth, Woodbury Avenue  Company Owned
#
#    Facility ID                                Features - Products  \
# 0        18228           Lunch, Oven-warmed Food, Reserve Amenity
# 1         9956                                                NaN
# 2        10933                                                NaN
# 3        16980  Lunch, Oven-warmed Food, Reserve Amenity, Sire...
# 4        17269           Lunch, Oven-warmed Food, Reserve Amenity
#
#                         Features - Service Features - Stations  Food Region  \
# ...

# %%
dfst["location"] = dfst[["Latitude","Longitude"]].apply(lambda x:asGeoJSON(x.Latitude,x.Longitude), axis=1)
dfst = dfst.loc[:, ['Brand', 'Name', "State",'location']]
dfst.head()
# Out:
#        Brand                         Name State  \
# 0  Starbucks               Epping Main St    NH
# 1  Starbucks      Stop & Shop-Exeter #204    NH
# 2  Starbucks      Target Greenland T-2530    NH
# 3  Starbucks       Seabrook, Lafayette Rd    NH
# 4  Starbucks  Portsmouth, Woodbury Avenue    NH
#
#                                             location
# 0  {'type': 'Point', 'coordinates': [-71.073203, ...
# 1  {'type': 'Point', 'coordinates': [-70.93204399...
# 2  {'type': 'Point', 'coordinates': [-70.816345, ...
# 3  {'type': 'Point', 'coordinates': [-70.86808, 4...
# 4  {'type': 'Point', 'coordinates': [-70.792327, ...

# %%
val=[]
for i in dfst.location:
    if haversine(coord,i["coordinates"]) < 50:
        val.append("YES")
    else:
        val.append("NO")
        
dfst.loc[:, "near_point"] = val

# %%
dfst.to_json("OUTPUT/Starbucks.json", orient="records")
# $ mongoimport --db starbucks --collection starbucks --jsonArray --drop OUTPUT/Starbucks.json

# %%
db, collst = connectMongoColl('starbucks','starbucks')

# %%
result = collst.aggregate([
    {
        '$geoNear': {
            'near': {
                'type': 'Point', 
                'coordinates': [
                    -122.214897, 37.772323
                ]
            }, 
            'distanceField': 'dist.calculated', 
            'minDistance': 2, 
            'spherical': True
        }
    }
])

# %%
# COMO SE HACE ESTO!!!!!

# %%
db, collst_dist = connectMongoColl('starbucks','starbucks_dist')

# %%
filt = {"Brand":1,"State":1,"location":1}
starb = list(collst_dist.find({"dist.calculated":{"$lte":10000}},filt))
df = pd.DataFrame(starb)
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# POR QUÉ NO FUNCIONA!

# %%
df = pd.read_csv("INPUT/starbucks.csv")
df = df.loc[:, ['Brand', 'Name', 'State','Latitude','Longitude']]
df = df.rename(columns={"Latitude":"latitude","Longitude":"longitude"})
df.head()
# Out:
#        Brand                         Name State   latitude  longitude
# 0  Starbucks               Epping Main St    NH  43.031873 -71.073203
# 1  Starbucks      Stop & Shop-Exeter #204    NH  42.989763 -70.932044
# 2  Starbucks      Target Greenland T-2530    NH  43.048710 -70.816345
# 3  Starbucks       Seabrook, Lafayette Rd    NH  42.882128 -70.868080
# 4  Starbucks  Portsmouth, Woodbury Avenue    NH  43.092318 -70.792327

# %%
gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.longitude, df.latitude))
gdf.head()
# Out:
#        Brand                         Name State   latitude  longitude  \
# 0  Starbucks               Epping Main St    NH  43.031873 -71.073203
# 1  Starbucks      Stop & Shop-Exeter #204    NH  42.989763 -70.932044
# 2  Starbucks      Target Greenland T-2530    NH  43.048710 -70.816345
# 3  Starbucks       Seabrook, Lafayette Rd    NH  42.882128 -70.868080
# 4  Starbucks  Portsmouth, Woodbury Avenue    NH  43.092318 -70.792327
#
#                      geometry
# 0  POINT (-71.07320 43.03187)
# 1  POINT (-70.93204 42.98976)
# 2  POINT (-70.81634 43.04871)
# 3  POINT (-70.86808 42.88213)
# 4  POINT (-70.79233 43.09232)

# %%
def get_distance(row):
    '''
    Esta función calcula la distancia en km entre el punto seleccionado y las coordenadas que pasamos como parámetro
    '''
    coord = (37.772323,-122.214897)
    dist = distance.distance(coord, (row.latitude, row.longitude)).km
    return round(dist, 2)

# %%
gdf['distance'] = gdf.apply(get_distance, axis=1)
gdf.head()
# Out:
#        Brand                         Name State   latitude  longitude  \
# 0  Starbucks               Epping Main St    NH  43.031873 -71.073203
# 1  Starbucks      Stop & Shop-Exeter #204    NH  42.989763 -70.932044
# 2  Starbucks      Target Greenland T-2530    NH  43.048710 -70.816345
# 3  Starbucks       Seabrook, Lafayette Rd    NH  42.882128 -70.868080
# 4  Starbucks  Portsmouth, Woodbury Avenue    NH  43.092318 -70.792327
#
#                      geometry  distance
# 0  POINT (-71.07320 43.03187)   4313.10
# 1  POINT (-70.93204 42.98976)   4325.25
# 2  POINT (-70.81634 43.04871)   4333.37
# 3  POINT (-70.86808 42.88213)   4332.53
# 4  POINT (-70.79233 43.09232)   4334.44

# %%
# filtrar gdf por los que están a menos de 5 km.
gdf = gdf[gdf["distance"]<5]
gdf
# Out:
#           Brand                             Name State   latitude   longitude  \
# 9161  Starbucks    Hegenberger & I-880 - Oakland    CA  37.737551 -122.197833
# 9169  Starbucks          Safeway - Alameda #2708    CA  37.756933 -122.252902
# 9170  Starbucks             Alameda Towne Center    CA  37.756954 -122.252896
# 9176  Starbucks  Park Street & Central - Alameda    CA  37.763977 -122.242714
# 9181  Starbucks      Tilden & Blanding - Alameda    CA  37.768227 -122.232459
# 9186  Starbucks                Fruitvale & I-880    CA  37.774365 -122.230338
# 9199  Starbucks           Estuary Cove - Oakland    CA  37.787948 -122.251006
# 9249  Starbucks             Safeway-Oakland #908    CA  37.801195 -122.215642
# 9265  Starbucks            3347 Lakeshore Avenue    CA  37.811189 -122.243417
#
#                          geometry  distance
# 9161  POINT (-122.19783 37.73755)      4.14
# 9169  POINT (-122.25290 37.75693)      3.76
# 9170  POINT (-122.25290 37.75695)      3.76
# ...

# %%
Map(Layer(gdf))
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.2.0-rc.2.1/airship.js&quot;></script>
# ...

# %% [markdown]
# ## 3 | School

# %%
school = getLocation(radius = 2000)

# %%
dschool = pd.DataFrame(school["results"])

# %%
dschool.head()
# Out:
#                                             geometry  \
# 0  {'location': {'lat': 37.7645032, 'lng': -122.2...
# 1  {'location': {'lat': 37.7755994, 'lng': -122.2...
# 2  {'location': {'lat': 37.7793766, 'lng': -122.2...
# 3  {'location': {'lat': 37.7787755, 'lng': -122.2...
# 4  {'location': {'lat': 37.7904349, 'lng': -122.2...
#
#                                                 icon  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3  https://maps.gstatic.com/mapfiles/place_api/ic...
# 4  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                          id  \
# 0  d69e15e88cd3a2d0a14b6cfc80db303a68e681d4
# 1  3b5324e357d2539e884c89065f0bb86cc5190c7e
# 2  76d76020e2dd748df52bd9b50f7fe953e6043c5b
# 3  97d1fcb3538f5f69fa13223b8c9b21587f60cf76
# 4  4854462f7c679ae1d141e81eb8b1ed5c3a6e2dce
#
# ...

# %%
lst_school=[]
for i in dschool.geometry:
    lst_school.append(i["location"])

# %%
dschool = pd.DataFrame(lst_school)
dschool = dschool.rename(columns={"lat":'latitude','lng':"longitude"})

# %%
gdfschool = gpd.GeoDataFrame(dschool, geometry=gpd.points_from_xy(dschool.longitude, dschool.latitude))
gdfschool.head()
# Out:
#     latitude   longitude                     geometry
# 0  37.764503 -122.234896  POINT (-122.23490 37.76450)
# 1  37.775599 -122.211805  POINT (-122.21181 37.77560)
# 2  37.779377 -122.230619  POINT (-122.23062 37.77938)
# 3  37.778776 -122.223856  POINT (-122.22386 37.77878)
# 4  37.790435 -122.237026  POINT (-122.23703 37.79043)

# %%
Map(Layer(gdfschool))
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.2.0-rc.2.1/airship.js&quot;></script>
# ...

# %% [markdown]
# ## 4 | Vegan

# %%
vegan = getLocation(radius = 2000,place="restaurant",keyword="vegan")

# %%
dfvegan = pd.DataFrame(vegan["results"])
dfvegan.head()
# Out:
#                                             geometry  \
# 0  {'location': {'lat': 37.7741025, 'lng': -122.2...
# 1  {'location': {'lat': 37.7757787, 'lng': -122.2...
#
#                                                 icon  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                          id                       name  \
# 0  4eaa581cd4440d9990cb67bdbfadcf432146a1eb  Two Mammas' Vegan Kitchen
# 1  cd679d31632113d6badafd3bed1ca424021d8e58        Obelisco Restaurant
#
#          opening_hours                                             photos  \
# 0  {'open_now': False}  [{'height': 3024, 'html_attributions': ['<a hr...
# 1  {'open_now': False}  [{'height': 3024, 'html_attributions': ['<a hr...
#
#                       place_id  \
# 0  ChIJN-u7lIqGj4ARJI075Af8J_k
# 1  ChIJT5Drt_SGj4ARdERe5rUs8q0
#
#                                            plus_code  rating  \
# ...

# %%
lst_vegan=[]
for i in dfvegan.geometry:
    lst_vegan.append(i["location"])

# %%
dfvegan = pd.DataFrame(lst_vegan)
dfvegan = dfvegan.rename(columns={"lat":'latitude','lng':"longitude"})

# %%
gdfvegan = gpd.GeoDataFrame(dfvegan, geometry=gpd.points_from_xy(dfvegan.longitude, dfvegan.latitude))
gdfvegan.head()
# Out:
#     latitude   longitude                     geometry
# 0  37.774102 -122.221344  POINT (-122.22134 37.77410)
# 1  37.775779 -122.223944  POINT (-122.22394 37.77578)

# %%
Map(Layer(gdfvegan))
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.2.0-rc.2.1/airship.js&quot;></script>
# ...

# %% [markdown]
# ## MERGE AND MAP

# %%
colsorder = ["place","name","latitude","longitude","geometry"]

# %%
gdfstarbucks = gdf.rename(columns ={"Brand":"place","Name":"name"}).drop(columns=["State","distance"]).reset_index(drop=True)
gdfstarbucks.head()
# Out:
#        place                             name   latitude   longitude  \
# 0  Starbucks    Hegenberger & I-880 - Oakland  37.737551 -122.197833
# 1  Starbucks          Safeway - Alameda #2708  37.756933 -122.252902
# 2  Starbucks             Alameda Towne Center  37.756954 -122.252896
# 3  Starbucks  Park Street & Central - Alameda  37.763977 -122.242714
# 4  Starbucks      Tilden & Blanding - Alameda  37.768227 -122.232459
#
#                       geometry
# 0  POINT (-122.19783 37.73755)
# 1  POINT (-122.25290 37.75693)
# 2  POINT (-122.25290 37.75695)
# 3  POINT (-122.24271 37.76398)
# 4  POINT (-122.23246 37.76823)

# %%
gdfparty["place"] = "Party"
gdfparty = gdfparty.loc[:, colsorder]
gdfparty.head()
# Out:
#    place                   name   latitude   longitude  \
# 0  Party             Party Spot  37.776357 -122.216319
# 1  Party     12th Street Lounge  37.774036 -122.221289
# 2  Party  La Frontera Nightclub  37.771166 -122.213862
# 3  Party             Mel's Loft  37.771209 -122.219721
# 4  Party             The Bricks  37.773972 -122.221187
#
#                       geometry
# 0  POINT (-122.21632 37.77636)
# 1  POINT (-122.22129 37.77404)
# 2  POINT (-122.21386 37.77117)
# 3  POINT (-122.21972 37.77121)
# 4  POINT (-122.22119 37.77397)

# %%
name_school=[]
for i in list(range(20)):
    name_school.append(school["results"][i]["name"])

gdfschool["place"] = "School"
gdfschool["name"] = name_school
gdfschool = gdfschool.loc[:, colsorder]
gdfschool.head()
# Out:
#     place                                       name   latitude   longitude  \
# 0  School                   Edison Elementary School  37.764503 -122.234896
# 1  School                      Aspire Public Schools  37.775599 -122.211805
# 2  School             International Community School  37.779377 -122.230619
# 3  School  St. Elizabeth Elementary & Middle Schools  37.778776 -122.223856
# 4  School                    Roosevelt Middle School  37.790435 -122.237026
#
#                       geometry
# 0  POINT (-122.23490 37.76450)
# 1  POINT (-122.21181 37.77560)
# 2  POINT (-122.23062 37.77938)
# 3  POINT (-122.22386 37.77878)
# 4  POINT (-122.23703 37.79043)

# %%
name_vegan=[]
for i in list(range(2)):
    name_vegan.append(vegan["results"][i]["name"])

gdfvegan["place"] = "Vegan"
gdfvegan["name"] = name_vegan
gdfvegan = gdfvegan.loc[:, colsorder]
gdfvegan.head()
# Out:
#    place                       name   latitude   longitude  \
# 0  Vegan  Two Mammas' Vegan Kitchen  37.774102 -122.221344
# 1  Vegan        Obelisco Restaurant  37.775779 -122.223944
#
#                       geometry
# 0  POINT (-122.22134 37.77410)
# 1  POINT (-122.22394 37.77578)

# %%
gdfresult = pd.concat([gdfparty, gdfstarbucks, gdfschool, gdfvegan],ignore_index=True)
gdfresult
# Out:
#         place                                         name   latitude  \
# 0       Party                                   Party Spot  37.776357
# 1       Party                           12th Street Lounge  37.774036
# 2       Party                        La Frontera Nightclub  37.771166
# 3       Party                                   Mel's Loft  37.771209
# 4       Party                                   The Bricks  37.773972
# 5   Starbucks                Hegenberger & I-880 - Oakland  37.737551
# 6   Starbucks                      Safeway - Alameda #2708  37.756933
# 7   Starbucks                         Alameda Towne Center  37.756954
# 8   Starbucks              Park Street & Central - Alameda  37.763977
# 9   Starbucks                  Tilden & Blanding - Alameda  37.768227
# 10  Starbucks                            Fruitvale & I-880  37.774365
# 11  Starbucks                       Estuary Cove - Oakland  37.787948
# ...

# %%
Map([Layer(gdfparty),Layer(gdfstarbucks),Layer(gdfschool),Layer(gdfvegan)])
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.2.0-rc.2.1/airship.js&quot;></script>
# ...

# %%
Map(Layout[Map(Layer(gdfparty)),Map(Layer(gdfstarbucks)),Map(Layer(gdfschool)),Map(Layer(gdfvegan))])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-151-013a47110c86> in <module>
# ----> 1 Map(Layout[Map(Layer(gdfparty)),Map(Layer(gdfstarbucks)),Map(Layer(gdfschool)), Map(Layer(gdfvegan))])
#
# TypeError: 'type' object is not subscriptable

# %%
#Meterle el punto encontrado, aeropuerto, startups, designcompanies y pintar todas en el mismo mapa con colores!
